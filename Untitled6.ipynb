# %%
a = int(input())
b = int(input())
c = int(input())

if (a >= b > c) or (b >= a > c) :
    print (int(a))
    print (int(c))
    print (int(b))
    
if (a >= c > b) or (c >= a > b) :
    print (int(a))
    print (int(b))
    print (int(c))

if (b >= c > a) or (c >= b > a) :
    print (int(b))
    print (int(a))
    print (int(c))

if c > b > a :
    print (c)
    print (a)
    print (b)

if c > a > b :
    print (c)
    print (b)
    print (a)

# %%
a = int(input())
b = int(input())
c = int(input())

if (a >= b > c) or (b >= a > c) :
    print (int(a))
    print (int(c))
    print (int(b))
    
if (a >= c > b) or (c >= a > b) :
    print (int(a))
    print (int(b))
    print (int(c))

if (b >= c > a) or (c >= b > a) :
    print (int(b))
    print (int(a))
    print (int(c))

if c > b > a :
    print (c)
    print (a)
    print (b)

if c > a > b :
    print (c)
    print (b)
    print (a)

# %%
a = int(input())
b = int(input())
c = int(input())

if (a == b > c) :
    print (int(a))
    print (int(c))
    print (int(b))
    
if (a == c > b) :
    print (int(a))
    print (int(b))
    print (int(c))

if (b == c > a) :
    print (int(b))
    print (int(a))
    print (int(c))
if a > b > c :
    print (int(a))
    print (int(c))
    print (int(b))
if a > c > b :
    print (int(a))
    print (int(b))
    print (int(c))
    
if b > a > c :
    print (int(b))
    print (int(c))
    print (int(a))
if b > c > a :
    print (int(b))
    print (int(a))
    print (int(c))

if c > b > a :
    print (int(c))
    print (int(a))
    print (int(b))

if c > a > b :
    print (int(c))
    print (int(b))
    print (int(a))
