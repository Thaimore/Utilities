# %%
s = str(input(''))
a = str('')
b = len(s)
c = 0
d = 0
x = 0
f = 1

for i in range (d,b+1,f): 
    a = s[d:x+1]
    if (a != s[d+1:x+2]) :
        d += 1
        x += 1
    print (a)
    while (a == s[d:x+1]) and (d <= b ):
        c += 1
        d += 1
        x += 1
    print (a, end = '')
    print (c, end = '')
    c = 0
    f = d
    
    print (d)
# Out:
# sagsg
# s
# s01
# a
# a02
# g
# g03
# s
# s04
# g
# g05
#
# 16

# %%
s = str(input(''))
x = 0
a = s[x]
b = s[x+1]
c = len(s)
d = 0
while x <= c:
    while a != b:
        a = s[x]
        if x == c - 1:
            print (a, end = '')
            print (d, end = '')
            x = c + 1
            break
        b = s[x+1]
        d = 0
        d = 1
        x += 1
        break
    if a != b:
        print (a, end = '')
        print (d, end = '')
    d = 1
    while a == b :
        d += 1
        a = s[x]
        if x == c - 1:
            print (a, end = '')
            print (d, end = '')
            x = c + 1
            break
        b = s[x+1]
        x += 1
# Out:
# ssddgg
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b0a9bd1fb0fe> in <module>
#      15     while a == b :
#      16         d += 1
# ---> 17         print (a, end = '')
#      18         print (d, end = '')
#      19         x += 1
#
# c:\program files (x86)\python38-32\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# c:\program files (x86)\python38-32\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
# ...

# %%
s = str(input(''))
x = 0
a = s[x]
b = s[x+1]
c = len(s)
d = 0
while x <= c:
    while a != b:
        a = s[x]
        if x == c - 1:
            print (a, end = '')
            print (d, end = '')
            x = c + 1
            break
        b = s[x+1]
        d = 0
        d = 1
        x += 1
        break
    if a != b:
        print (a, end = '')
        print (d, end = '')
    d = 1
    while a == b :
        d += 1
        a = s[x]
        if x == c - 1:
            print (a, end = '')
            print (d, end = '')
            x = c + 1
            break
        b = s[x+1]
        if (a != b) and (d < c):
            print (a, end = '')
            print (d - 1, end = '')
        if (a != b) and (d > c) :
            print (a, end = '')
            print (d, end = '')
        x += 1

# %%
s = str(input(''))
x = 0
a = 0
b = 0
c = len(s)
d = 0
for i in range (c+1) :
    a = s[i]
    b = s[i+1]
    if a == b :
        d = 1
        d += 1
        if (b != s[i+2]) :
            print (a, end = '')
            print (d, end = '')
            
    if a != b :
        d = 1
        print (a, end = '')
        print (d, end = '')
# Out:
# asaagsg
# a1s1a2a1g1s1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-de0801a5a75c> in <module>
#       7 for i in range (c+1) :
#       8     a = s[i]
# ----> 9     b = s[i+1]
#      10     if a == b :
#      11         d = 1
#
# IndexError: string index out of range

# %%
z = str(input(''))
x = '    '
s = z + x
print (s)
a = 0
b = 0
c = len(s)
d = 1
for i in range (c+1) :
    a = s[i]
    #if (i == c - 1) :
        #print (x)
    b = s[i+1]
    if a == b :
        d += 1
        if (b != s[i+2]) :
            print (a, end = '')
            print (d, end = '')
            
    if a != b :
        d = 1
        print (a, end = '')
        print (d, end = '')
# Out:
# afsgggg
# afsgggg
# a1f1s1g1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-4b3f590bb7ed> in <module>
#      11     #if (i == c - 1) :
#      12         #print (x)
# ---> 13     b = s[i+1]
#      14     if a == b :
#      15         d += 1
#
# IndexError: string index out of range

# %%
z = str(input(''))
x = '    '
s = z + x
print (s)
# Out:
# sasasfag
# sasasfag

# %%
z = str(input(''))
x = '    '
s = z + x
a = 0
b = 0
e = len(x)
f = len(s)
c = f - e
d = 1
j = 0

for i in range (c+1) :
    if a == b:
        i = i + 1
    a = s[i]
    #if (i == c - 1) :
        #print (x)
    b = s[i+1]
    if a == b :
        d += 1
        if (b != s[i+2]) :
            print (a, end = '')
            print (d, end = '')
            a = b
            
    if (a != b) and (b != ''):
        d = 1
        if i < c - 1 :
            print (a, end = '')
            print (d, end = '')
# Out:
# aaaabbcaa
# a3a1a1b2c1c1a2

# %%
z = str(input(''))
x = '    '
s = z + x
j = 0
a = s[j]
b = s[j+1]
e = len(x)
f = len(s)
c = f - e
d = 1

while j < c:
    while a == b :
        a = s[j]
        b = s[j+1]
        if a!= s[j+1] :
            print (a, end = '')
            print (d, end = '')
        d += 1
        j += 1
    while (a != b) and (a != s[j+1]):
        d = 1
        a = s[j]
        b = s[j+1]
        print (a, end = '')
        print (d, end = '')
        j += 1
# Out:
# aaaabb
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e87892e43764> in <module>
#      21     while a != b :
#      22         d = 1
# ---> 23         print (a, end = '')
#      24         print (d, end = '')
#      25         j += 1
#
# c:\program files (x86)\python38-32\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# c:\program files (x86)\python38-32\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
# ...

# %%
z = str(input(''))
x = '  '
s = z + x
j = 0
a = s[j]
b = s[j+1]
e = len(x)
f = len(s)
c = len (s)
d = 1
i = 0

while i < c + 1 :
    a = s[i]
    #if i == c - 2:
        #break
    while a == s[i+1]:
        d += 1
        i += 1
        a = s[i]

    print (a, end = '')
    print (d, end = '')
    d = 1
    i = i + 1

# %%
z = str(input(''))
x = '  '
s = z + x
j = 0
a = s[j]
b = s[j+1]
e = len(x)
f = len(s)
c = len (s)
d = 1
i = 0

while i < c  :
    a = s[i]

    if i != (c - 2) :
        while a == s[i+1]:
            d += 1
            i += 1
            a = s[i]
    else :
        break
    print (a, end = '')
    print (d, end = '')
    d = 1
    i = i + 1
